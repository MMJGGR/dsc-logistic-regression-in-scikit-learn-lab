# %% [markdown]
# # Logistic Regression in scikit-learn - Lab
#
# ## Introduction
#
# In this lab, you are going to fit a logistic regression model to a dataset concerning heart disease. Whether or not a patient has heart disease is indicated in the column labeled `'target'`. 1 is for positive for heart disease while 0 indicates no heart disease.
#
# ## Objectives
#
# In this lab you will:
#
# - Fit a logistic regression model using scikit-learn
#
#
# ## Let's get started!
#
# Run the following cells that import the necessary functions and import the dataset:

# %%
# Import necessary functions
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
# Import data
df = pd.read_csv('https://raw.githubusercontent.com/MMJGGR/dsc-logistic-regression-in-scikit-learn-lab/master/heart.csv', index_col=0)
df.head()
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 63     1   3       145   233    1        0      150      0      2.3      0
# 37     1   2       130   250    0        1      187      0      3.5      0
# 41     0   1       130   204    0        0      172      0      1.4      2
# 56     1   1       120   236    0        1      178      0      0.8      2
# 57     0   0       120   354    0        1      163      1      0.6      2
#
#      ca  thal  target
# age
# 63    0     1       1
# 37    0     2       1
# 41    0     2       1
# 56    0     2       1
# 57    0     2       1

# %% [markdown]
# ## Define appropriate `X` and `y`
#
# Recall the dataset contains information about whether or not a patient has heart disease and is indicated in the column labeled `'target'`. With that, define appropriate `X` (predictors) and `y` (target) in order to model whether or not a patient has heart disease.

# %%
# Split the data into target and predictors
y = df['target']
X = df.drop("target", axis =1)

# %% [markdown]
# ## Train- test split
#
# - Split the data into training and test sets
# - Assign 25% to the test set
# - Set the `random_state` to 0
#
# N.B. To avoid possible data leakage, it is best to split the data first, and then normalize.

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state = 0)

# %% [markdown]
# ## Normalize the data
#
# Normalize the data (`X`) prior to fitting the model.

# %%
# Your code here
from sklearn.preprocessing import MinMaxScaler

scalar = MinMaxScaler()
scalar.fit(X_train)

X = pd.DataFrame(
    scalar.transform(X_train),
    index = X_train.index,
    columns = X_train.columns
)
X.head()
# Out:
#      sex        cp  trestbps      chol  fbs  restecg   thalach  exang  \
# age
# 58   1.0  0.666667  0.387755  0.214781  0.0      0.0  0.778626    0.0
# 52   1.0  0.000000  0.183673  0.228637  0.0      0.5  0.679389    0.0
# 54   1.0  0.666667  0.571429  0.233256  0.0      0.0  0.717557    0.0
# 59   1.0  1.000000  0.857143  0.321016  0.0      0.0  0.564885    0.0
# 67   1.0  0.000000  0.265306  0.226328  0.0      0.0  0.442748    1.0
#
#       oldpeak  slope    ca      thal
# age
# 58   0.516129    1.0  0.50  1.000000
# 52   0.000000    1.0  0.25  0.666667
# 54   0.258065    1.0  0.00  1.000000
# 59   0.677419    0.0  0.00  1.000000
# 67   0.419355    0.5  0.50  1.000000

# %% [markdown]
# ## Fit a model
#
# - Instantiate `LogisticRegression`
#   - Make sure you don't include the intercept
#   - set `C` to a very large number such as `1e12`
#   - Use the `'liblinear'` solver
# - Fit the model to the training data

# %%
# Instantiate the model
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(fit_intercept=False, C = 1e12, solver='liblinear')

# Fit the model
model_log = logreg.fit(X_train,y_train)
model_log
# Out:
# LogisticRegression(C=1000000000000.0, fit_intercept=False, solver='liblinear')

# %% [markdown]
# ## Predict
# Generate predictions for the training and test sets.

# %%
# Generate predictions
y_hat_train = logreg.predict(X_train)
y_hat_test = logreg.predict(X_test)

# %% [markdown]
# ## How many times was the classifier correct on the training set?

# %%
# Your code here
train_residuals = np.abs(y_train - y_hat_train)
print(pd.Series(train_residuals, name="Residuals (counts)").value_counts())
print()
print(pd.Series(train_residuals, name="Residuals (proportions)").value_counts(normalize=True))
# Out:
# 0    193
# 1     34
# Name: Residuals (counts), dtype: int64
#
# 0    0.85022
# 1    0.14978
# Name: Residuals (proportions), dtype: float64

# %% [markdown]
# ## How many times was the classifier correct on the test set?

# %%
# Your code here
train_residuals = np.abs(y_train - y_hat_train)
print(pd.Series(train_residuals, name="Residuals (counts)").value_counts())
print()
print(pd.Series(train_residuals, name="Residuals (proportions)").value_counts(normalize=True))

# %% [markdown]
# ## Analysis
# Describe how well you think this initial model is performing based on the training and test performance. Within your description, make note of how you evaluated performance as compared to your previous work with regression.

# %%
# Your analysis here
test_residuals = np.abs(y_test - y_hat_test)
print(pd.Series(test_residuals, name="Residuals (counts)").value_counts())
print()
print(pd.Series(test_residuals, name="Residuals (proportions)").value_counts(normalize=True))
# Out:
# 0    63
# 1    13
# Name: Residuals (counts), dtype: int64
#
# 0    0.828947
# 1    0.171053
# Name: Residuals (proportions), dtype: float64

# %% [markdown]
# ## Summary
#
# In this lab, you practiced a standard data science pipeline: importing data, split it into training and test sets, and fit a logistic regression model. In the upcoming labs and lessons, you'll continue to investigate how to analyze and tune these models for various scenarios.
